# %%
h = 6.62607015e-34
c = 299792458
pi = 3.14159265359
hbar = h/(2 * pi)
e = 1.602176634e-19
me = 9.10938370e-31
ep0 = 8.85418781e-12

a_0= (4*ep0*pi*hbar**2)/(me*e**2)

print(a_0)
# Out:
# 5.291772108258437e-11
